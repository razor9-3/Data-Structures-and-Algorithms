# %% [markdown]
# ### Задание №1
# Массив A состоит из целых положительных чисел длин отрезков. Составьте из трех отрезков такой треугольник, чтобы его периметр был максимально возможным. Если невозможно составить треугольник с положительной площадью функция возвращает 0.

# %%
arr = [4,5,9,7,5,4,7,8,5,4,9,0]
def triangle(arr):
    a = sorted(arr)
    i = len(arr) - 1
    n = 0
    ans = 0
    if(i >= 3):
        while n < 3:
            ans = ans + a[i]
            n += 1
            i -= 1
    return (ans)
ans = triangle (arr)
print(ans)
# Out:
# 26

# %% [markdown]
# ### Задание №2
# Дан массив неотрицательных целых чисел nums. Расположите их в таком порядке, чтобы вместе они образовали максимально возможное число. Замечание: Результат может быть очень большим числом, поэтому представьте его как string, а не integer.

# %%
import math
def sort(arr, compare, left, right):
    if right - left <= 1: return
    z = arr[left + (right - left) // 2]
    l = left
    r = right - 1
    while l <= r:
        while compare(arr[l], z) < 0: l += 1
        while compare(arr[r], z) > 0: r -= 1
        if l <= r:
            arr[r], arr[l] = arr[l], arr[r]
            l += 1
            r -= 1
    if left < r: sort(arr, compare, left, r + 1)
    if l < right: sort(arr, compare, l, right)

def max_val(nums):
    
    def compare(a, b):
        n_a = math.ceil(math.log(a, 10))
        n_b = math.ceil(math.log(b, 10))
        d_a = 10 ** (n_a - 1)
        d_b = 10 ** (n_b - 1)
        n = min(n_a, n_b)
        for i in range(n):
            digit_a = a // d_a
            digit_b = b // d_b
            if digit_a > digit_b: return 1
            if digit_a < digit_b: return -1
            d_a //= 10
            d_b //= 10
        if n_a == n_b: return 0
        if n_a < n_b:
            digit_a = a % 10
            digit_b = (b % (d_b * 10)) // d_b
            if digit_a > digit_b: return 1
            if digit_a < digit_b: return -1
            return 0
        if n_a > n_b:
            digit_a = (a % (d_a * 10)) // d_a
            digit_b = b % 10
            if digit_a > digit_b: return 1
            if digit_a < digit_b: return -1
            return 0
        
    sort(nums, lambda a, b: -compare(a, b), 0, len(nums))
    return ''.join([str(num) for num in nums])

max_val([9,16,39,81])
# Out:
# '9813916'

# %% [markdown]
# ### Задание №3
# Дана матрица mat размером m * n, значения целочисленные. Напишите функцию, сортирующую каждую диагональ матрицы по возрастанию и возвращающую получившуюся матрицу.

# %%
def sort(get_item, set_item, left, right):
    if right - left <= 1: return
    z = get_item(left + (right - left) // 2)
    l = left
    r = right - 1
    while l <= r:
        while get_item(l) < z: l += 1
        while get_item(r) > z: r -= 1
        if l <= r:
            item_l = get_item(l)
            item_r = get_item(r)
            set_item(l, item_r)
            set_item(r, item_l)
            l += 1
            r -= 1
    if left < r: sort(get_item, set_item, left, r + 1)
    if l < right: sort(get_item, set_item, l, right)
        
def diagonal_sort(mat, m, n):
    s = min(m, n)
    
    def set_main_diagonal(i, v):
        mat[i][i] = v
    def set_sub_diagonal(i, v):
        mat[s - i - 1][i] = v
    
    sort(lambda i: mat[s - i - 1][i], set_sub_diagonal, 0, s)
    sort(lambda i: mat[i][i], set_main_diagonal, 0, s)

def print_matrix(mat):
    for row in mat:
        print(' '.join(map(str,row)))

m, n = 3, 3
mat = [
        [6, 4, 9], 
        [9, 2, 5],
        [8, 1, 2]
      ]

print("--- Before sort ---")
print_matrix(mat)

diagonal_sort(mat, m, n)

print("--- After sort ----")
print_matrix(mat)
# Out:
# --- Before sort ---
# 6 4 9
# 9 2 5
# 8 1 2
# --- After sort ----
# 2 4 9
# 9 6 5
# 2 1 8
